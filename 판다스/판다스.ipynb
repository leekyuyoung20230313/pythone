# %%
# 구글창에 uci 머신러닝 검색
import numpy as np
import pandas as pd

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data'

# %%
help(pd.read_csv)

# %%
from tables.table import Column
df_data =  pd.read_csv(url,header=None, sep='\s+')                       
df_data.columns = ['CRIM','ZN','INDUS','CHAS','NOX', 'RM',  'AGE',  'DIS',  'RAD',  'TAX',  'PTRATIO',  'B',  'LSTAT',   'MEDV']
df_data

# %%
df_data.head(2)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
#
#    PTRATIO      B  LSTAT  MEDV
# 0     15.3  396.9   4.98  24.0
# 1     17.8  396.9   9.14  21.6

# %%
df_data.tail(2)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9

# %%
# 넘파이는 수학연산... 행렬간의 연산 미 기타등등..
# 파일로드(csv ,xlsx) 및 데이터 로드, 데이터 분할 및 분석등....   -- 판다스

# %%
# !pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df_excel = pd.read_excel('./excel-comp-data.xlsx')
df_excel.head()
# Out:
#    account                         name                                street  \
# 0   211829   Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563               Walter-Trantow                     1311 Alvis Tunnel
# 2   648336   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3   109996  D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4   121213                Bauch-Goldner                   7274 Marissa Common
#
#               city          state  postal-code     Jan     Feb    Mar
# 0       New Jaycob          Texas        28752   10000   62000  35000
# 1    Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 2   New Lilianland           Iowa        76517   91000  120000  35000
# 3       Hyattburgh          Maine        46021   45000  120000  10000
# 4  Shanahanchester     California        49681  162000  120000  35000

# %%
df_excel.head().T
# Out:
#                                       0                  1  \
# account                          211829             320563
# name         Kerluke, Koepp and Hilpert     Walter-Trantow
# street               34456 Sean Highway  1311 Alvis Tunnel
# city                         New Jaycob      Port Khadijah
# state                             Texas      NorthCarolina
# postal-code                       28752              38365
# Jan                               10000              95000
# Feb                               62000              45000
# Mar                               35000              35000
#
#                                                 2  \
# account                                    648336
# name                   Bashirian, Kunde and Price
# street       62184 Schamberger Underpass Apt. 231
# city                               New Lilianland
# state                                        Iowa
# postal-code                                 76517
# ...

# %%
# df_excel 컬럼정보만 추출
df_excel.columns
# Out:
# Index(['account', 'name', 'street', 'city', 'state', 'postal-code', 'Jan',
#        'Feb', 'Mar'],
#       dtype='object')

# %%
df_excel['account']
# Out:
# 0     211829
# 1     320563
# 2     648336
# 3     109996
# 4     121213
# 5     132971
# 6     145068
# 7     205217
# 8     209744
# 9     212303
# 10    214098
# 11    231907
# 12    242368
# 13    268755
# 14    273274
# Name: account, dtype: int64

# %%
df_excel[['account']]
# Out:
#     account
# 0    211829
# 1    320563
# 2    648336
# 3    109996
# 4    121213
# 5    132971
# 6    145068
# 7    205217
# 8    209744
# 9    212303
# 10   214098
# 11   231907
# 12   242368
# 13   268755
# 14   273274

# %%
# account street state 정보만 추출
# df_excel[['account', 'street', 'state']]
df_excel[df_excel.columns[:6:2]]
# Out:
#     account                                street          state
# 0    211829                    34456 Sean Highway          Texas
# 1    320563                     1311 Alvis Tunnel  NorthCarolina
# 2    648336  62184 Schamberger Underpass Apt. 231           Iowa
# 3    109996           155 Fadel Crescent Apt. 144          Maine
# 4    121213                   7274 Marissa Common     California
# 5    132971                  89403 Casimer Spring       Arkansas
# 6    145068          340 Consuela Bridge Apt. 400     Mississipi
# 7    205217          91971 Cronin Vista Suite 601    RhodeIsland
# 8    209744                      26739 Grant Lock   Pennsylvania
# 9    212303             366 Maggio Grove Apt. 998          Idaho
# 10   214098             649 Cierra Forks Apt. 078       Tenessee
# 11   231907              18115 Olivine Throughway    NorthDakota
# 12   242368                       182 Bertie Road           Iowa
# ...

# %%
df_excel[:3]
# Out:
#    account                        name                                street  \
# 0   211829  Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563              Walter-Trantow                     1311 Alvis Tunnel
# 2   648336  Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
#
#              city          state  postal-code    Jan     Feb    Mar
# 0      New Jaycob          Texas        28752  10000   62000  35000
# 1   Port Khadijah  NorthCarolina        38365  95000   45000  35000
# 2  New Lilianland           Iowa        76517  91000  120000  35000

# %%
df_excel[:3]
# Out:
#    account                        name                                street  \
# 0   211829  Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563              Walter-Trantow                     1311 Alvis Tunnel
# 2   648336  Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
#
#              city          state  postal-code    Jan     Feb    Mar
# 0      New Jaycob          Texas        28752  10000   62000  35000
# 1   Port Khadijah  NorthCarolina        38365  95000   45000  35000
# 2  New Lilianland           Iowa        76517  91000  120000  35000

# %%
df_excel[['account','name']][:3]
# Out:
#    account                        name
# 0   211829  Kerluke, Koepp and Hilpert
# 1   320563              Walter-Trantow
# 2   648336  Bashirian, Kunde and Price

# %%
# 1 csv 파일 로드
# 2 엑셀파일 로드
# 특정 컬럼에 해당하는 시리즈 객체만 출력
# 인덱스만 출력, 값만 출력,  값들의 최대 최소 평균 도 구해봅시다

# 특정 컬럼에 해당하는 데이터 프레임 객체만 출력
# 컬럼명 출력
# 앞에서 5개 출력
# 뒤에서 5개 출력
# 행렬처럼 특정 row의 col만 추출 ex)  (3,2)형태로 출력

# %%
# 넘파이 처럼 행렬 로 자유롭게 사용....
df_excel.head(2)
# Out:
#    account                        name              street           city  \
# 0   211829  Kerluke, Koepp and Hilpert  34456 Sean Highway     New Jaycob
# 1   320563              Walter-Trantow   1311 Alvis Tunnel  Port Khadijah
#
#            state  postal-code    Jan    Feb    Mar
# 0          Texas        28752  10000  62000  35000
# 1  NorthCarolina        38365  95000  45000  35000

# %%
df_temp = df_excel.head()

# %%
df_temp.index = ['a','b','c','d','e']

# %%
df_temp.loc[ ['a','b'],['account','name']]
# Out:
#    account                        name
# a   211829  Kerluke, Koepp and Hilpert
# b   320563              Walter-Trantow

# %%
df_temp = df_excel.head()
df_temp
# Out:
#    account                         name                                street  \
# 0   211829   Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563               Walter-Trantow                     1311 Alvis Tunnel
# 2   648336   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3   109996  D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4   121213                Bauch-Goldner                   7274 Marissa Common
#
#               city          state  postal-code     Jan     Feb    Mar
# 0       New Jaycob          Texas        28752   10000   62000  35000
# 1    Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 2   New Lilianland           Iowa        76517   91000  120000  35000
# 3       Hyattburgh          Maine        46021   45000  120000  10000
# 4  Shanahanchester     California        49681  162000  120000  35000

# %%
df_temp.index = df_temp['account']

# %%
df_temp
# Out:
#          account                         name  \
# account
# 211829    211829   Kerluke, Koepp and Hilpert
# 320563    320563               Walter-Trantow
# 648336    648336   Bashirian, Kunde and Price
# 109996    109996  D'Amore, Gleichner and Bode
# 121213    121213                Bauch-Goldner
#
#                                        street             city          state  \
# account
# 211829                     34456 Sean Highway       New Jaycob          Texas
# 320563                      1311 Alvis Tunnel    Port Khadijah  NorthCarolina
# 648336   62184 Schamberger Underpass Apt. 231   New Lilianland           Iowa
# 109996            155 Fadel Crescent Apt. 144       Hyattburgh          Maine
# 121213                    7274 Marissa Common  Shanahanchester     California
#
#          postal-code     Jan     Feb    Mar
# account
# 211829         28752   10000   62000  35000
# 320563         38365   95000   45000  35000
# 648336         76517   91000  120000  35000
# ...

# %%
df_temp.loc[ [320563,648336] , ['account','name']  ]
# Out:
#          account                        name
# account
# 320563    320563              Walter-Trantow
# 648336    648336  Bashirian, Kunde and Price

# %%
df_temp.loc[320563: , ['account','name']  ]
# Out:
#          account                         name
# account
# 320563    320563               Walter-Trantow
# 648336    648336   Bashirian, Kunde and Price
# 109996    109996  D'Amore, Gleichner and Bode
# 121213    121213                Bauch-Goldner

# %%
df_temp.loc[320563: , 'account':  ]
# Out:
#          account                         name  \
# account
# 320563    320563               Walter-Trantow
# 648336    648336   Bashirian, Kunde and Price
# 109996    109996  D'Amore, Gleichner and Bode
# 121213    121213                Bauch-Goldner
#
#                                        street             city          state  \
# account
# 320563                      1311 Alvis Tunnel    Port Khadijah  NorthCarolina
# 648336   62184 Schamberger Underpass Apt. 231   New Lilianland           Iowa
# 109996            155 Fadel Crescent Apt. 144       Hyattburgh          Maine
# 121213                    7274 Marissa Common  Shanahanchester     California
#
#          postal-code     Jan     Feb    Mar
# account
# 320563         38365   95000   45000  35000
# 648336         76517   91000  120000  35000
# 109996         46021   45000  120000  10000
# 121213         49681  162000  120000  35000

# %%
df_temp.loc[320563: , 'account':  'city']
# Out:
#          account                         name  \
# account
# 320563    320563               Walter-Trantow
# 648336    648336   Bashirian, Kunde and Price
# 109996    109996  D'Amore, Gleichner and Bode
# 121213    121213                Bauch-Goldner
#
#                                        street             city
# account
# 320563                      1311 Alvis Tunnel    Port Khadijah
# 648336   62184 Schamberger Underpass Apt. 231   New Lilianland
# 109996            155 Fadel Crescent Apt. 144       Hyattburgh
# 121213                    7274 Marissa Common  Shanahanchester

# %%
df_temp.index = df_temp['city']

# %%
df_temp
# Out:
#                  account                         name  \
# city
# New Jaycob        211829   Kerluke, Koepp and Hilpert
# Port Khadijah     320563               Walter-Trantow
# New Lilianland    648336   Bashirian, Kunde and Price
# Hyattburgh        109996  D'Amore, Gleichner and Bode
# Shanahanchester   121213                Bauch-Goldner
#
#                                                street             city  \
# city
# New Jaycob                         34456 Sean Highway       New Jaycob
# Port Khadijah                       1311 Alvis Tunnel    Port Khadijah
# New Lilianland   62184 Schamberger Underpass Apt. 231   New Lilianland
# Hyattburgh                155 Fadel Crescent Apt. 144       Hyattburgh
# Shanahanchester                   7274 Marissa Common  Shanahanchester
#
#                          state  postal-code     Jan     Feb    Mar
# city
# New Jaycob               Texas        28752   10000   62000  35000
# ...

# %%
df_temp.loc['New Lilianland':,'city':'state']
# Out:
#                             city       state
# city
# New Lilianland    New Lilianland        Iowa
# Hyattburgh            Hyattburgh       Maine
# Shanahanchester  Shanahanchester  California

# %%
df = pd.read_csv('./도로교통공단_최근5년 교통사고 통계_20211231.csv', encoding='cp949')

# %%
# 발생년 -> 발생년도
temp = df.columns.to_numpy()
temp[0] = '발생년도'
temp
# Out:
# array(['발생년도', '사고건수', '사망자수', '중상자수', '경상자수', '부상신고자수'], dtype=object)

# %%
df.columns = temp
df
# Out:
#    발생년도    사고건수  사망자수   중상자수    경상자수  부상신고자수
# 0  2017  216335  4185  78212  223200   21417
# 1  2018  217148  3781  74258  227511   21268
# 2  2019  229600  3349  72306  245524   23882
# 3  2020  209654  3081  60564  226036   19594
# 4  2021  203130  2916  55905  219283   16420

# %%
df.reset_index()
# Out:
#    index  발생년도    사고건수  사망자수   중상자수    경상자수  부상신고자수
# 0      0  2017  216335  4185  78212  223200   21417
# 1      1  2018  217148  3781  74258  227511   21268
# 2      2  2019  229600  3349  72306  245524   23882
# 3      3  2020  209654  3081  60564  226036   19594
# 4      4  2021  203130  2916  55905  219283   16420

# %%
df.reset_index(drop=True)
# Out:
#    발생년도    사고건수  사망자수   중상자수    경상자수  부상신고자수
# 0  2017  216335  4185  78212  223200   21417
# 1  2018  217148  3781  74258  227511   21268
# 2  2019  229600  3349  72306  245524   23882
# 3  2020  209654  3081  60564  226036   19594
# 4  2021  203130  2916  55905  219283   16420

# %%
df.index = df['발생년도']
df
# Out:
#       발생년도    사고건수  사망자수   중상자수    경상자수  부상신고자수
# 발생년도
# 2017  2017  216335  4185  78212  223200   21417
# 2018  2018  217148  3781  74258  227511   21268
# 2019  2019  229600  3349  72306  245524   23882
# 2020  2020  209654  3081  60564  226036   19594
# 2021  2021  203130  2916  55905  219283   16420

# %%
df.drop(columns=['발생년도'], inplace=True)
# df = df.drop(columns=['발생년도'])

# %%
df.reset_index(inplace=True)

# %%
df.set_index('발생년도',drop=True)
# Out:
#         사고건수  사망자수   중상자수    경상자수  부상신고자수
# 발생년도
# 2017  216335  4185  78212  223200   21417
# 2018  217148  3781  74258  227511   21268
# 2019  229600  3349  72306  245524   23882
# 2020  209654  3081  60564  226036   19594
# 2021  203130  2916  55905  219283   16420

# %%
df.set_index('발생년도').reset_index()
# Out:
#    발생년도    사고건수  사망자수   중상자수    경상자수  부상신고자수
# 0  2017  216335  4185  78212  223200   21417
# 1  2018  217148  3781  74258  227511   21268
# 2  2019  229600  3349  72306  245524   23882
# 3  2020  209654  3081  60564  226036   19594
# 4  2021  203130  2916  55905  219283   16420

# %%
# Dataframe에서 인덱스변경은 set_index()
# 인덱스 초기화 : reset_index()

# %%
df = df.set_index('발생년도')
df
# Out:
#         사고건수  사망자수   중상자수    경상자수  부상신고자수
# 발생년도
# 2017  216335  4185  78212  223200   21417
# 2018  217148  3781  74258  227511   21268
# 2019  229600  3349  72306  245524   23882
# 2020  209654  3081  60564  226036   19594
# 2021  203130  2916  55905  219283   16420

# %%
# loc VS iloc
df.iloc[:3,:3]
# Out:
#         사고건수  사망자수   중상자수
# 발생년도
# 2017  216335  4185  78212
# 2018  217148  3781  74258
# 2019  229600  3349  72306

# %%
df.loc[:2019, :'중상자수']
# Out:
#         사고건수  사망자수   중상자수
# 발생년도
# 2017  216335  4185  78212
# 2018  217148  3781  74258
# 2019  229600  3349  72306

# %%
df
# Out:
#         사고건수  사망자수   중상자수    경상자수  부상신고자수
# 발생년도
# 2017  216335  4185  78212  223200   21417
# 2018  217148  3781  74258  227511   21268
# 2019  229600  3349  72306  245524   23882
# 2020  209654  3081  60564  226036   19594
# 2021  203130  2916  55905  219283   16420

# %%
df.drop(2018,inplace=True)

# %%
df
# Out:
#         사고건수  사망자수   중상자수    경상자수  부상신고자수
# 발생년도
# 2017  216335  4185  78212  223200   21417
# 2019  229600  3349  72306  245524   23882
# 2020  209654  3081  60564  226036   19594
# 2021  203130  2916  55905  219283   16420

# %%
# 판다스
# loc vs iloc  
# set_index(), reset_index()

# %%
df = df.reset_index()
