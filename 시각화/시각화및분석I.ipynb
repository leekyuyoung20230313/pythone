# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/leekyuyoung20230313/pythone/main/%EC%8B%9C%EA%B0%81%ED%99%94/data/auto-mpg.csv'
df = pd.read_csv(url,header= None)
df.columns = ['mpg',
'cylinders',
'displacement',
'horsepower',
'weight',
'acceleration',
'model year',
'origin',
'car name']

# %%
# 데이터 프레임의 일부 내용 확인
print(df.head())
print()
print(df.tail())
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
#
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# ...

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.shape
# Out:
# (398, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
# 기술 통계
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.describe(include='all')
# Out:
#                mpg   cylinders  displacement horsepower       weight  \
# count   398.000000  398.000000    398.000000        398   398.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN      150.0          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.514573    5.454774    193.425879        NaN  2970.424623
# std       7.815984    1.701004    104.269838        NaN   846.841774
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.250000        NaN  2223.750000
# 50%      23.000000    4.000000    148.500000        NaN  2803.500000
# 75%      29.000000    8.000000    262.000000        NaN  3608.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
#         acceleration  model year      origin    car name
# count     398.000000  398.000000  398.000000         398
# ...

# %%
# 각 열의 데이터의 개수
df.count()
# Out:
# mpg             398
# cylinders       398
# displacement    398
# horsepower      398
# weight          398
# acceleration    398
# model year      398
# origin          398
# car name        398
# dtype: int64

# %%
# origin 데이터 개수 확인 : 특정 컬럼
df['origin'].value_counts()
# Out:
# 1    249
# 3     79
# 2     70
# Name: origin, dtype: int64

# %%
# 평균을 구하려고 할때 - 수치형이 아니면 에러가 발생하는 경우가 있음(local jupyter notebook)
# 1. 수치데이터만 가지고 평균을 구한다
# 2. 수치형 문자열 데이터를 수치형으로 변환한다

# %%
# 1. 수치데이터만 가지고 평균을 구한다
df.describe().columns
df.loc[:, df.describe().columns].mean()
# Out:
# mpg               23.514573
# cylinders          5.454774
# displacement     193.425879
# weight          2970.424623
# acceleration      15.568090
# model year        76.010050
# origin             1.572864
# dtype: float64

# %%
# 2. 수치형 문자열 데이터를 수치형으로 변환한다
# df['horsepower'] = df['horsepower'].str.replace('?', '').replace('',np.nan).astype(np.float64)
# df.info()

# %%
df['mpg'].mean()
# Out:
# 23.514572864321607

# %%
df.median()
# Out:
# <ipython-input-17-6d467abf240d>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# mpg               23.0
# cylinders          4.0
# displacement     148.5
# weight          2803.5
# acceleration      15.5
# model year        76.0
# origin             1.0
# dtype: float64

# %%
df['mpg'].median()
# Out:
# 23.0

# %%
# min, max, median, std
# 상관계수

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.corr()
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model year      1.000000  0.180662
# origin          0.180662  1.000000

# %%
# excel
df = pd.read_excel('./남북한발전전력량.xlsx')
df.head()
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# 2  2658  2802  3196  3343  3430  3581  3427  3402  3523
# 3  1510  1478  1486  1547  1503  1388  1564  1648  1620
# 4     -     -     -     -    86   118   151   173   195
#
# [5 rows x 29 columns]

# %%
df.tail()
# Out:
#   전력량 (억㎾h) 발전 전력별 1990 1991 1992 1993 1994 1995 1996 1997  ... 2007 2008  \
# 4       NaN    신재생    -    -    -    -    -    -    -    -  ...    -    -
# 5        북한     합계  277  263  247  221  231  230  213  193  ...  236  255
# 6       NaN     수력  156  150  142  133  138  142  125  107  ...  133  141
# 7       NaN     화력  121  113  105   88   93   88   88   86  ...  103  114
# 8       NaN    원자력    -    -    -    -    -    -    -    -  ...    -    -
#
#   2009 2010 2011 2012 2013 2014 2015 2016
# 4    -    -    -   86  118  151  173  195
# 5  235  237  211  215  221  216  190  239
# 6  125  134  132  135  139  130  100  128
# 7  110  103   79   80   82   86   90  111
# 8    -    -    -    -    -    -    -    -
#
# [5 rows x 29 columns]

# %%
df.set_index(['전력량 (억㎾h)','발전 전력별'])
# Out:
#                   1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  \
# 전력량 (억㎾h) 발전 전력별
# 남한        합계      1077  1186  1310  1444  1650  1847  2055  2244  2153  2393
# NaN       수력        64    51    49    60    41    55    52    54    61    61
#           화력       484   573   696   803  1022  1122  1264  1420  1195  1302
#           원자력      529   563   565   581   587   670   739   771   897  1031
#           신재생        -     -     -     -     -     -     -     -     -     -
# 북한        합계       277   263   247   221   231   230   213   193   170   186
# NaN       수력       156   150   142   133   138   142   125   107   102   103
#           화력       121   113   105    88    93    88    88    86    68    83
#           원자력        -     -     -     -     -     -     -     -     -     -
#
#                   ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 전력량 (억㎾h) 발전 전력별  ...
# 남한        합계      ...  4031  4224  4336  4747  4969  5096  5171  5220  5281
# ...

# %%
# 남북한 합계가 있는 row만 추출
df_sn = df.iloc[ [0,5], 2:]
df_sn.reset_index(drop=True,inplace=True)

# %%
df_sn.index = ['South','North']
df_sn
# Out:
#        1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  ...  2007  \
# South  1077  1186  1310  1444  1650  1847  2055  2244  2153  2393  ...  4031
# North   277   263   247   221   231   230   213   193   170   186  ...   236
#
#        2008  2009  2010  2011  2012  2013  2014  2015  2016
# South  4224  4336  4747  4969  5096  5171  5220  5281  5404
# North   255   235   237   211   215   221   216   190   239
#
# [2 rows x 27 columns]

# %%
# 판다스 내장 그래프
df_sn.plot()
# Out:
# <Axes: >

# %%
tdf_sn =  df_sn.T
print(tdf_sn.head())
tdf_sn.plot()
# Out:
#      South North
# 1990  1077   277
# 1991  1186   263
# 1992  1310   247
# 1993  1444   221
# 1994  1650   231
# <Axes: >

# %%
# 막대 그래프 : 범주형(category) 데이터를 시각화
tdf_sn.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(tdf_sn)
plt.xticks(rotation=90)
plt.subplot(1,2,2)
plt.bar(tdf_sn.index,tdf_sn['South'].values)
plt.bar(tdf_sn.index,tdf_sn['North'].values)
plt.xticks(rotation=90)
plt.show()

# %%
tdf_sn['North'].values
# Out:
# array([277, 263, 247, 221, 231, 230, 213, 193, 170, 186, 194, 202, 190,
#        196, 206, 215, 225, 236, 255, 235, 237, 211, 215, 221, 216, 190,
#        239], dtype=object)

# %%
# 히스토그램 : 계급구간..
tdf_sn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries, 1990 to 2016
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   South   27 non-null     object
#  1   North   27 non-null     object
# dtypes: object(2)
# memory usage: 1.7+ KB

# %%
tdf_sn = tdf_sn.astype(np.int64)

# %%
tdf_sn.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# 산점도 : 데이터 대략적인 분포를 알수 있음 - 상관관계를 파악
url = 'https://raw.githubusercontent.com/leekyuyoung20230313/pythone/main/%EC%8B%9C%EA%B0%81%ED%99%94/data/auto-mpg.csv'
df = pd.read_csv(url,header= None)
df.columns = ['mpg',
'cylinders',
'displacement',
'horsepower',
'weight',
'acceleration',
'model year',
'origin',
'car name']

# %%
df.plot(x = 'weight', y='mpg', kind='scatter')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
# 박스플롯 : 특정 변수의 데이터 분포와 분산 정도에 대한 정보 : 이상치(outlier) 탐색
df['mpg'].plot(kind='box')
plt.show()

# %%
# 시도별 전출입 인구수
df = pd.read_excel("./시도별 전출입 인구수.xlsx",header=0)
df.head(2)
# Out:
# /usr/local/lib/python3.9/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    전출지별  전입지별      1970      1971      1972      1973      1974      1975  \
# 0  전출지별  전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1    전국    전국   4046536   4210164   3687938   4860418   5297969   9011440
#
#        1976      1977  ...      2008      2009      2010      2011      2012  \
# 0  이동자수 (명)  이동자수 (명)  ...  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1   6773250   7397623  ...   8808256   8487275   8226594   8127195   7506691
#
#        2013      2014      2015      2016      2017
# 0  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1   7411784   7629098   7755286   7378430   7154226
#
# [2 rows x 50 columns]

# %%
# 실제데이터만 추출 하고 결측치 처리
df2 = df.iloc[1:]
df2 = df2.fillna(method='ffill')

# %%
# 결측치를 확인하는 다양한 방법
# df.isna().sum()
# df.isna().mean()
# df[df.isna().any(axis=1)]

# %%
df2.head(2)
# Out:
#   전출지별   전입지별     1970     1971     1972     1973     1974     1975     1976  \
# 1   전국     전국  4046536  4210164  3687938  4860418  5297969  9011440  6773250
# 2   전국  서울특별시  1742813  1671705  1349333  1831858  2050392  3396662  2756510
#
#       1977  ...     2008     2009     2010     2011     2012     2013  \
# 1  7397623  ...  8808256  8487275  8226594  8127195  7506691  7411784
# 2  2893403  ...  2025358  1873188  1733015  1721748  1555281  1520090
#
#       2014     2015     2016     2017
# 1  7629098  7755286  7378430  7154226
# 2  1573594  1589431  1515602  1472937
#
# [2 rows x 50 columns]

# %%
# 서울에서 다른지역으로 이동한 데이터
df_seoul = df2[ (df2['전출지별'] == '서울특별시') & (df2['전입지별'] != '서울특별시') ]
df_seoul.reset_index(drop=True,inplace=True)

# %%
df_seoul = df_seoul.drop(['전출지별'], axis=1)
df_seoul = df_seoul.rename({'전입지별':'전입지'},axis=1)

# %%
df_seoul = df_seoul.set_index('전입지')
df_seoul.head()
# Out:
#           1970     1971     1972     1973     1974     1975     1976     1977  \
# 전입지
# 전국     1448985  1419016  1210559  1647268  1819660  2937093  2495620  2678007
# 부산광역시    11568    11130    11768    16307    22220    27515    23732    27213
# 대구광역시        -        -        -        -        -        -        -        -
# 인천광역시        -        -        -        -        -        -        -        -
# 광주광역시        -        -        -        -        -        -        -        -
#
#           1978     1979  ...     2008     2009     2010     2011     2012  \
# 전입지                      ...
# 전국     3028911  2441242  ...  2083352  1925452  1848038  1834806  1658928
# 부산광역시    29856    28542  ...    17353    17738    17418    18816    16135
# 대구광역시        -        -  ...     9720    10464    10277    10397    10135
# 인천광역시        -        -  ...    50493    45392    46082    51641    49640
# 광주광역시        -        -  ...    10846    11725    11095    10587    10154
#
# ...

# %%
# 서울에서 경기도로 이동한 데이터 만 추출
df_seoul_ggd =  df_seoul.loc['경기도']
df_seoul_ggd.plot()
plt.show()

# %%
# 코렙 한글
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# ...

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
plt.figure(figsize=(12,5))
plt.plot(df_seoul_ggd.index, df_seoul_ggd.values, marker='o', label = '서울->경기도')
plt.title("서울 -> 경기도")
plt.xlabel("기간")
plt.ylabel("이동 인구수")
plt.xticks(rotation=90,size=10)
plt.style.use('ggplot')
plt.legend()

plt.annotate('',
             xy=(20,620000),  # 화살표 머리부분(끝점)
             xytext=(2,290000), #화살표의 꼬리부분(시작점)
             xycoords='data', #좌표체계
             arrowprops=dict(arrowstyle='->', color='skyblue', lw=5) # 화살표 서식
)
plt.annotate('인구증가(1972 ~ 1995)',
             xy=(10,400000),  # 텍스트 위치 기준점
             rotation = 35,
             va = 'baseline', # 텍스트 상하정렬
             ha = 'center', # 텍스트 좌우 정렬
             fontsize = 15
)


plt.show()

# %%
df_seoul.index[1:]
# Out:
# Index(['부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시', '세종특별자치시', '경기도',
#        '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도', '경상남도', '제주특별자치도'],
#       dtype='object', name='전입지')

# %%
import random
random.randrange(2)
# Out:
# 1

# %%
plt.figure(figsize=(12,10))
for loc in df_seoul.index[1:]:
  temp = df_seoul.loc[loc].replace('-',np.nan)
  plt.plot(temp.index, temp.values, marker='o', c = (random.random(), random.random(), random.random()) , label = f'서울->{loc}')  

plt.title("서울 -> 타지역")
plt.xlabel("기간")
plt.ylabel("이동 인구수")
plt.xticks(rotation=90,size=10)
plt.style.use('ggplot')
plt.legend()
plt.show()

# %%
df_inSeoul = df2[(df2['전입지별'] == '서울특별시') & (df2['전출지별'] != '서울특별시')]

# %%
df_inSeoul = df_inSeoul.drop(['전입지별'],axis=1)
df_inSeoul = df_inSeoul.set_index(['전출지별'])

# %%
df_inSeoul.head(2)
# Out:
#           1970     1971     1972     1973     1974     1975     1976     1977  \
# 전출지별
# 전국     1742813  1671705  1349333  1831858  2050392  3396662  2756510  2893403
# 부산광역시    24263    30144    18260    24251    30284    59914    43416    42685
#
#           1978     1979  ...     2008     2009     2010     2011     2012  \
# 전출지별                     ...
# 전국     3307439  2589667  ...  2025358  1873188  1733015  1721748  1555281
# 부산광역시    48142    39673  ...    25249    24459    23116    23016    21437
#
#           2013     2014     2015     2016     2017
# 전출지별
# 전국     1520090  1573594  1589431  1515602  1472937
# 부산광역시    19621    20616    19441    19236    19460
#
# [2 rows x 48 columns]

# %%
plt.figure(figsize=(12,10))
for loc in df_inSeoul.index[1:]:
  temp = df_inSeoul.loc[loc].replace('-',np.nan)
  plt.plot(temp.index, temp.values, marker='o', c = (random.random(), random.random(), random.random()),label = f'{loc}->서울')  

plt.title("타지역->서울")
plt.xlabel("기간")
plt.ylabel("이동 인구수")
plt.xticks(rotation=90,size=10)
plt.style.use('ggplot')
plt.legend()
plt.show()

# %%
#화면을 4등분해서.. 경기와 서울을 제외하고. 나머지 지역에 대한 전입데이터를 시각화
# 서울 -> 타지역... (경기도 제외하고)
city4 = df_seoul.index[1:5]
city4
# Out:
# Index(['부산광역시', '대구광역시', '인천광역시', '광주광역시'], dtype='object', name='전입지')

# %%
from matplotlib import markers
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
df_seoul.loc[city4[1]].replace('-',np.nan)

df_seoul = df_seoul.replace('-',np.nan)

ax1.plot(df_seoul.loc[city4[0]], marker='o', c ='green', label=f'서울->{city4[0]}'  )
ax2.plot(df_seoul.loc[city4[1]], marker='o', c ='blue',label=f'서울->{city4[1]}'  )
ax3.plot(df_seoul.loc[city4[2]], marker='o', c ='red',label=f'서울->{city4[2]}'  )
ax4.plot(df_seoul.loc[city4[3]], marker='o', c ='orange',label=f'서울->{city4[3]}'  )

ax1.legend()
ax1.set_title(f'서울->{city4[0]}')
ax2.legend()
ax2.set_title(f'서울->{city4[1]}')
ax3.legend()
ax3.set_title(f'서울->{city4[2]}')
ax4.legend()
ax4.set_title(f'서울->{city4[3]}')

plt.show()

# %%
df_seoul.columns
# Out:
# Index(['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017'],
#       dtype='object')
