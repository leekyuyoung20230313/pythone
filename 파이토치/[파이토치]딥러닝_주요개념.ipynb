# %% [markdown]
# 인공신경망

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 퍼셉트론

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 단점

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# MLP(Multi Layer Perceptron)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 활성화 함수

# %% [markdown]
# 시그모이드

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ReLu 함수

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# LeekyRelu
#   - x : x>0
#   - 0.01x : x<=0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 손실함수
#   - 평균제곱오차 MSE : 회귀
#   - 교차 엔트로피 Cross Entropy : 분류

# %% [markdown]
# # 경사하강법
#   - 가장 가파른 아래 뱡향
#   - 조금씩

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 학습률이 너무 작으면?
#    - 내려오다가 끝남.. 학습이 완료되지 못함.. epoch 늘려줘야함
# - 학습률이 너무 크면
#   - 범위를 벗어난다.. 학습이 안됨

# %% [markdown]
# 효율적인 학습을 위해서는? - 확률적 경가하강법== 미니배치 경사하강법
#   - 전체데이터에서 임의의 데이터를 뽑아서 경사하강법을 수행
#   - 임의의 데이터를 뽑아서--> 미니배치

# %% [markdown]
# # 순전파(forward propagation) , 역전파(back....)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 순전파
#   - predication
#
# 역전파
#   - 가중치 업데이트

# %% [markdown]
# 그래프
#   - 각각의 계산과정을 단일 노드형태로 분리해서 표현
#   - 각 단계마다 미분값을 저장하고 있다
#   - gradientTap : keras
#   - backward : torch
#   - 덧셈노드는 이전 미분계수를 by pass
#   - 곱셈노드는 이전 미분계수에다가 x,y를  서로 바꾼다

# %% [markdown]
# # CNN(합성곱) : 이미지에서 특성을 추출하기 위해 만든 (시신경을 흉내)
#   - 필터
#   - 폴링

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 패딩과 스트라이딩

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 입력데이터의 크기를 N, 필터의 크기를 K, 패딩 크기를 P 스트라이드를 S

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 커널크기하고 스트라이드를 같게 하면? - 반으로 줄여진다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 합성곱 신경망 전체구조

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 성능향상 - 드랍아웃

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 배치정규화
#   - 과적합 방지와 훈련속도 향상
#   - 내부 공변량 변화 : 신경망 계층마다 입력 데이터 분포가 다른현상
#     - 입력데이터 분포가 다르면 훈련속도가 느려짐
#     - 계층간 분포의 편차를 줄이는작업
#   - 평균이 0, 분산이 1이 되도록 정규화

# %% [markdown]
# 최적화
#   - 옵티마이저

# %% [markdown]
# SGD
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 모멘텀
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Adagrad
#    - 적응적 학습률(Adaptive learning rate)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# RMSProp
#    - Adagrade의 단점 보완..  훈련을 진행할 수록 학습률이 0에까가워 진다 - >학습이 안됨
#    - 기울기만 고려해서 학습률을 낮춰감

# %% [markdown]
# Adam
#   - 모멘텀 + RMSProp의 장점을 결합
#   - 관성을 이용하면서 RMSProp처럼 적응적 학습률을 사용

# %% [markdown]
# 전이학습
#
# ![image.png](data:image/png;base64,...)
