# %%
import tensorflow as tf

# %%
(x_train,y_train),(x_test,y_test) = tf.keras.datasets.fashion_mnist.load_data()
x_train.shape
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28)

# %% [markdown]
# 컨볼류션
#   - 인간의 시신경을 흉내낸 알고리즘
#   - 특징을 추출해서 해당 특징만 모아서 판단
#
# 커널 = 필터 = 가중치
#   - 합성곱
#   - 특성 맵

# %%
# 합성곱층... 컨볼류션
tf.keras.layers.Conv2D(10,kernel_size=(3,3),activation='relu')

# %% [markdown]
# 패딩

# %%
tf.keras.layers.Conv2D(10,kernel_size=(3,3),activation='relu',padding='same')

# %% [markdown]
# 스트라이드

# %%
tf.keras.layers.Conv2D(10,kernel_size=(3,3),activation='relu',padding='same',strides=1)

# %% [markdown]
# 폴링

# %%
tf.keras.layers.MaxPool2D(2,strides=2,padding='valid')

# %% [markdown]
# 합성곱 신경망
#   -이미지(2x2) - 합성곱층 - 폴링층 - flatten - Dense
#
#   ![image.png](data:image/png;base64,...)
